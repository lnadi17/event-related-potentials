# %%
# !pip install pyxdf mne pandas jupyterlab ipympl ipywidgets
# Out:
# Requirement already satisfied: pyxdf in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (1.17.2)
# Requirement already satisfied: mne in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (1.8.0)
# Requirement already satisfied: pandas in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (2.3.3)
# Requirement already satisfied: jupyterlab in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (4.5.2)
# Requirement already satisfied: ipympl in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: ipywidgets in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (8.1.8)
# Requirement already satisfied: numpy>=2.0.2 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from pyxdf) (2.0.2)
# Requirement already satisfied: decorator in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from mne) (5.2.1)
# Requirement already satisfied: jinja2 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from mne) (3.9.4)
# Requirement already satisfied: packaging in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from mne) (25.0)
# Requirement already satisfied: pooch>=1.5 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from mne) (1.13.1)
# Requirement already satisfied: tqdm in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from mne) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (8.7.0)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (6.31.0)
# Requirement already satisfied: jupyter-core in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (5.8.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (44.1.1)
# Requirement already satisfied: tomli>=1.2.2 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (2.3.0)
# Requirement already satisfied: tornado>=6.2.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (6.5.2)
# Requirement already satisfied: traitlets in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: ipython<10 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipympl) (8.18.1)
# Requirement already satisfied: pillow in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipympl) (11.3.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: typing_extensions>=4.0.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from async-lru>=1.0.0->jupyterlab) (4.15.0)
# Requirement already satisfied: anyio in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab) (4.11.0)
# Requirement already satisfied: certifi in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: idna in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyterlab) (3.23.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.8.17)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (27.1.0)
# Requirement already satisfied: jedi>=0.16 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipython<10->ipympl) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipython<10->ipympl) (2.19.2)
# Requirement already satisfied: stack-data in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: exceptiongroup in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipython<10->ipympl) (1.3.0)
# Requirement already satisfied: pexpect>4.3 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from ipython<10->ipympl) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jinja2->mne) (3.0.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-core->jupyterlab) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.32.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (3.2.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from matplotlib>=3.6->mne) (6.5.2)
# Requirement already satisfied: six>=1.5 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython<10->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (2.5.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from stack-data->ipython<10->ipympl) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from stack-data->ipython<10->ipympl) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from stack-data->ipython<10->ipympl) (0.2.3)
# Requirement already satisfied: webencodings in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fqdn in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.1.0)
# Requirement already satisfied: uri-template in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.8)
# Requirement already satisfied: pycparser in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.23)
# Requirement already satisfied: lark>=1.2.2 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /Users/luka/PycharmProjects/visual-evoked-potentials/.venv/lib/python3.9/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
print(sys.version)
# Out:
# 3.9.6 (default, Apr 30 2025, 02:07:17)
# [Clang 17.0.0 (clang-1700.0.13.5)]

# %%
import matplotlib.pyplot as plt
import mne
import pandas as pd
import os
import numpy as np
from src import UnicornData

# %%
data_path = '../../data/n170'
data_file = 'n170_nani'

# %%
os.listdir(data_path)
# Out:
# ['n170_maria.csv', 'n170_nani.csv', 'n170_maria.xdf', 'n170_nani.xdf']

# %%
csv_data = pd.read_csv(f'{data_path}/{data_file}.csv')
csv_data.head()
# Out:
#              timestamp_iso  trial_index             image_file class  \
# 0  2025-10-23T08:33:26.152            1             car_17.jpg   car
# 1  2025-10-23T08:33:27.750            2             car_32.jpg   car
# 2  2025-10-23T08:33:29.265            3   scrambled_car_27.jpg   car
# 3  2025-10-23T08:33:30.799            4  scrambled_face_33.jpg  face
# 4  2025-10-23T08:33:32.313            5             car_37.jpg   car
#
#    scrambled  marker_code resp_key  correct    rt_ms  stim_time_s  isi_s  \
# 0          0           57    right        1  1353.36          0.3  1.155
# 1          0           72    right        1   924.69          0.3  1.289
# 2          1          167     left        1   605.82          0.3  1.199
# 3          1          133     left        1   588.47          0.3  1.216
# 4          0           77    right        1   758.31          0.3  1.192
#
#    shown_width_units  shown_height_units
# 0             1.0500                 0.6
# 1             0.8514                 0.6
# 2             0.8681                 0.6
# 3             0.5806                 0.6
# 4             0.8393                 0.6

# %%
scrambled_idx = csv_data[csv_data['scrambled'] == 0].index.values
unscrambled_idx = csv_data[csv_data['scrambled'] == 1].index.values

# %%
scrambled_idx, unscrambled_idx
# Out:
# (array([  0,   1,   4,   6,   8,   9,  10,  19,  21,  22,  23,  24,  25,
#          27,  28,  30,  33,  34,  37,  38,  42,  45,  46,  47,  48,  50,
#          51,  55,  57,  58,  60,  62,  64,  66,  67,  70,  73,  75,  76,
#          77,  80,  83,  84,  85,  87,  90,  92,  97,  98, 101, 103, 104,
#         109, 111, 117, 118, 119, 120, 122, 123, 124, 125, 126, 127, 128,
#         129, 131, 138, 141, 142, 143, 145, 147, 151, 152, 153, 154, 157,
#         158, 159]),
#  array([  2,   3,   5,   7,  11,  12,  13,  14,  15,  16,  17,  18,  20,
#          26,  29,  31,  32,  35,  36,  39,  40,  41,  43,  44,  49,  52,
#          53,  54,  56,  59,  61,  63,  65,  68,  69,  71,  72,  74,  78,
#          79,  81,  82,  86,  88,  89,  91,  93,  94,  95,  96,  99, 100,
#         102, 105, 106, 107, 108, 110, 112, 113, 114, 115, 116, 121, 130,
#         132, 133, 134, 135, 136, 137, 139, 140, 144, 146, 148, 149, 150,
#         155, 156]))

# %%
faces_idx = csv_data[csv_data['class'] == 'car'].index.values
cars_idx = csv_data[csv_data['class'] == 'face'].index.values
faces_idx = np.intersect1d(unscrambled_idx, faces_idx)
cars_idx = np.intersect1d(unscrambled_idx, cars_idx)

# %%
CONST_OFFSET = 0.073  # Delay measured with photodiode that day
data = UnicornData(f'{data_path}/{data_file}.xdf', delay=CONST_OFFSET)
raw = data.filter().raw
raw
# Out:
# Markers 321
# Data 0
# Data 0
# Data 0
# Data 89971
# Markers 321
# Creating RawArray with float64 data, n_channels=8, n_times=89971
#     Range : 0 ... 89970 =      0.000 ...   359.880 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 1651 samples (6.604 s)
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# <RawArray | 8 x 89971 (359.9 s), ~5.5 MB, data loaded>

# %%
TARGET_MARKER = 1
RESPONSE_MARKER = 2

# %%
events = data.events

# %%
# Event codes (ERP CORE)
CODES_FACE_START = 1          # 1–40
CODES_CAR_START  = 41         # 41–80
CODES_SF_START   = 101        # 101–140
CODES_SC_START   = 141        # 141–180
RESP_CORRECT = 201
RESP_INCORRECT = 202

# %%
face_events = np.linspace(1, 40, 40).astype(int)
car_events = np.linspace(41, 80, 40).astype(int)

# %%
events = mne.merge_events(events, face_events, 1)
events = mne.merge_events(events, car_events, 2)
events
# Out:
# array([[11383,     0,     2],
#        [11744,     0,   201],
#        [11748,     0,     2],
#        [12143,     0,   201],
#        [12147,     0,   167],
#        [12522,     0,   201],
#        [12527,     0,   133],
#        [12905,     0,   201],
#        [12909,     0,     2],
#        [13284,     0,   201],
#        [13288,     0,   145],
#        [13654,     0,   201],
#        [13662,     0,     1],
#        [14016,     0,   201],
#        [14020,     0,   105],
#        [14415,     0,   201],
#        [14420,     0,     1],
#        [14799,     0,   201],
#        [14803,     0,     1],
#        [15194,     0,   201],
#        [15198,     0,     1],
#        [15572,     0,   201],
#        [15577,     0,   116],
#        [15972,     0,   201],
#        [15976,     0,   137],
#        [16339,     0,   201],
#        [16342,     0,   123],
#        [16696,     0,   201],
#        [16700,     0,   159],
#        [17075,     0,   201],
#        [17079,     0,   173],
#        [17428,     0,   201],
#        [17433,     0,   176],
#        [17795,     0,   201],
#        [17799,     0,   122],
#        [18169,     0,   201],
#        [18174,     0,   143],
#        [18557,     0,   201],
#        [18561,     0,     2],
#        [18918,     0,   201],
#        [18922,     0,   136],
#        [19289,     0,   202],
#        [19293,     0,     1],
#        [19642,     0,   201],
#        [19647,     0,     2],
#        [20009,     0,   201],
#        [20013,     0,     2],
#        [20371,     0,   201],
#        [20375,     0,     2],
#        [20758,     0,   201],
#        [20766,     0,     1],
#        [21125,     0,   201],
#        [21128,     0,   147],
#        [21524,     0,   201],
#        [21528,     0,     1],
#        [21886,     0,   201],
#        [21890,     0,     1],
#        [22252,     0,   201],
#        [22256,     0,   179],
#        [22610,     0,   201],
#        [22614,     0,     2],
#        [23014,     0,   201],
#        [23018,     0,   118],
#        [23413,     0,   201],
#        [23417,     0,   168],
#        [23792,     0,   201],
#        [23796,     0,     1],
#        [24187,     0,   201],
#        [24192,     0,     1],
#        [24553,     0,   201],
#        [24558,     0,   154],
#        [24944,     0,   201],
#        [24949,     0,   157],
#        [25303,     0,   201],
#        [25307,     0,     1],
#        [25660,     0,   201],
#        [25668,     0,     1],
#        [26056,     0,   201],
#        [26060,     0,   177],
#        [26426,     0,   201],
#        [26434,     0,   138],
#        [26805,     0,   201],
#        [26809,     0,   178],
#        [27163,     0,   201],
#        [27167,     0,     2],
#        [27550,     0,   201],
#        [27558,     0,   140],
#        [27924,     0,   201],
#        [27929,     0,   169],
#        [28316,     0,   201],
#        [28320,     0,     1],
#        [28682,     0,   201],
#        [28690,     0,     1],
#        [29069,     0,   201],
#        [29073,     0,     2],
#        [29427,     0,   201],
#        [29431,     0,     2],
#        [29822,     0,   201],
#        [29826,     0,   129],
#        [30180,     0,   201],
#        [30184,     0,     2],
#        [30571,     0,   201],
#        [30576,     0,     2],
#        [30954,     0,   201],
#        [30962,     0,   141],
#        [31333,     0,   201],
#        [31341,     0,   171],
#        [31737,     0,   201],
#        [31749,     0,   163],
#        [32115,     0,   201],
#        [32123,     0,     2],
#        [32473,     0,   201],
#        [32477,     0,   156],
#        [32856,     0,   201],
#        [32864,     0,     1],
#        [33218,     0,   201],
#        [33222,     0,     2],
#        [33576,     0,   201],
#        [33584,     0,   162],
#        [33959,     0,   201],
#        [33964,     0,     1],
#        [34333,     0,   201],
#        [34337,     0,   174],
#        [34700,     0,   201],
#        [34703,     0,     1],
#        [35087,     0,   201],
#        [35091,     0,   180],
#        [35445,     0,   201],
#        [35448,     0,     2],
#        [35811,     0,   201],
#        [35815,     0,   170],
#        [36202,     0,   201],
#        [36206,     0,     2],
#        [36597,     0,   201],
#        [36601,     0,     2],
#        [36993,     0,   201],
#        [37000,     0,   106],
#        [37354,     0,   201],
#        [37363,     0,   131],
#        [37742,     0,   201],
#        [37754,     0,     2],
#        [38142,     0,   201],
#        [38149,     0,   153],
#        [38540,     0,   201],
#        [38545,     0,   119],
#        [38899,     0,   201],
#        [38903,     0,     1],
#        [39265,     0,   201],
#        [39269,     0,   110],
#        [39648,     0,   201],
#        [39652,     0,     2],
#        [40031,     0,   201],
#        [40035,     0,     1],
#        [40409,     0,   201],
#        [40413,     0,     1],
#        [40804,     0,   201],
#        [40809,     0,   120],
#        [41200,     0,   201],
#        [41204,     0,   152],
#        [41575,     0,   201],
#        [41579,     0,     2],
#        [41937,     0,   201],
#        [41941,     0,   158],
#        [42311,     0,   201],
#        [42315,     0,   166],
#        [42665,     0,   201],
#        [42669,     0,     1],
#        [43060,     0,   201],
#        [43068,     0,     2],
#        [43456,     0,   201],
#        [43460,     0,     1],
#        [43855,     0,   201],
#        [43863,     0,   126],
#        [44221,     0,   201],
#        [44226,     0,     1],
#        [44587,     0,   201],
#        [44592,     0,   128],
#        [44958,     0,   201],
#        [44962,     0,   114],
#        [45349,     0,   201],
#        [45354,     0,     2],
#        [45736,     0,   201],
#        [45740,     0,   115],
#        [46132,     0,   201],
#        [46139,     0,     2],
#        [46515,     0,   201],
#        [46519,     0,   151],
#        [46893,     0,   201],
#        [46897,     0,   172],
#        [47284,     0,   201],
#        [47288,     0,   125],
#        [47671,     0,   201],
#        [47676,     0,   165],
#        [48067,     0,   201],
#        [48071,     0,     1],
#        [48420,     0,   201],
#        [48425,     0,     1],
#        [48791,     0,   202],
#        [48799,     0,   175],
#        [49157,     0,   201],
#        [49162,     0,   124],
#        [49553,     0,   201],
#        [49561,     0,     2],
#        [49911,     0,   201],
#        [49915,     0,   150],
#        [50289,     0,   201],
#        [50294,     0,     2],
#        [50676,     0,   201],
#        [50680,     0,     2],
#        [51046,     0,   201],
#        [51051,     0,   104],
#        [51409,     0,   201],
#        [51413,     0,   148],
#        [51787,     0,   201],
#        [51795,     0,   102],
#        [52174,     0,   201],
#        [52179,     0,   132],
#        [52528,     0,   201],
#        [52532,     0,     2],
#        [52903,     0,   202],
#        [52907,     0,   111],
#        [53281,     0,   201],
#        [53285,     0,     2],
#        [53639,     0,   201],
#        [53643,     0,   155],
#        [54039,     0,   201],
#        [54043,     0,   109],
#        [54401,     0,   201],
#        [54405,     0,   101],
#        [54800,     0,   201],
#        [54805,     0,   117],
#        [55183,     0,   201],
#        [55187,     0,   139],
#        [55558,     0,   201],
#        [55566,     0,     2],
#        [55957,     0,   201],
#        [55962,     0,     2],
#        [56328,     0,   201],
#        [56332,     0,     2],
#        [56686,     0,   201],
#        [56690,     0,     1],
#        [57077,     0,   201],
#        [57085,     0,   146],
#        [57464,     0,   202],
#        [57468,     0,     2],
#        [57834,     0,   201],
#        [57838,     0,     1],
#        [58234,     0,   201],
#        [58242,     0,     2],
#        [58637,     0,   201],
#        [58642,     0,     1],
#        [59004,     0,   201],
#        [59008,     0,     2],
#        [59403,     0,   201],
#        [59407,     0,     1],
#        [59757,     0,   201],
#        [59761,     0,     1],
#        [60115,     0,   201],
#        [60119,     0,     1],
#        [60497,     0,   201],
#        [60506,     0,   121],
#        [60893,     0,   201],
#        [60901,     0,     2],
#        [61251,     0,   202],
#        [61259,     0,   135],
#        [61630,     0,   201],
#        [61637,     0,   103],
#        [62012,     0,   201],
#        [62017,     0,   107],
#        [62412,     0,   201],
#        [62416,     0,   113],
#        [62795,     0,   201],
#        [62803,     0,   130],
#        [63161,     0,   201],
#        [63166,     0,   127],
#        [63524,     0,   201],
#        [63527,     0,     1],
#        [63902,     0,   201],
#        [63906,     0,   160],
#        [64276,     0,   201],
#        [64280,     0,   149],
#        [64647,     0,   201],
#        [64651,     0,     2],
#        [65042,     0,   201],
#        [65046,     0,     1],
#        [65421,     0,   201],
#        [65425,     0,     2],
#        [65791,     0,   201],
#        [65796,     0,   144],
#        [66166,     0,   201],
#        [66170,     0,     1],
#        [66528,     0,   201],
#        [66532,     0,   142],
#        [66911,     0,   201],
#        [66915,     0,     1],
#        [67314,     0,   201],
#        [67319,     0,   164],
#        [67677,     0,   201],
#        [67681,     0,   108],
#        [68080,     0,   201],
#        [68084,     0,   134],
#        [68472,     0,   201],
#        [68475,     0,     1],
#        [68866,     0,   201],
#        [68871,     0,     2],
#        [69254,     0,   201],
#        [69258,     0,     1],
#        [69624,     0,   201],
#        [69628,     0,     1],
#        [70016,     0,   201],
#        [70019,     0,   112],
#        [70419,     0,   201],
#        [70427,     0,   161],
#        [70814,     0,   201],
#        [70822,     0,     1],
#        [71197,     0,   201],
#        [71202,     0,     2],
#        [71584,     0,   201],
#        [71592,     0,     1],
#        [71975,     0,   201]])

# %%
picks = ["PO8"]
event_dict = dict(face=1, car=2)
tmin, tmax = -0.2, 1
epochs = data.create_epochs(picks, event_dict, tmin, tmax)
# Out:
# Not setting metadata
# 2 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 2 events and 301 original time points ...
# 0 bad epochs dropped

# %%
epochs.average().plot(picks=picks)
plt.show()
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
mne.viz.plot_compare_evokeds(
    {"Target": epochs['face'].average()},
    # combine='mean',
    show=True
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
# face_epochs = epochs[faces_idx]
# car_epochs = epochs[cars_idx]

# %%
mne.viz.plot_compare_evokeds(
    {"Faces": epochs['face'].average(), "Cars": epochs['car'].average()},
    picks=picks,
    # combine='mean',
    show=True
)
# Out:
# [<Figure size 800x600 with 2 Axes>]
