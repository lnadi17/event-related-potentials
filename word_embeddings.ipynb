# %%
# !pip install sentence_transformers
# Out:
# Requirement already satisfied: sentence_transformers in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (5.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from sentence_transformers) (4.57.1)
# Requirement already satisfied: tqdm in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from sentence_transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from sentence_transformers) (1.7.2)
# Requirement already satisfied: scipy in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from sentence_transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from sentence_transformers) (0.36.0)
# Requirement already satisfied: Pillow in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from sentence_transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from sentence_transformers) (4.15.0)
# Requirement already satisfied: filelock in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2025.10.23)
# Requirement already satisfied: requests in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (1.1.10)
# Requirement already satisfied: sympy>=1.13.3 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (3.5)
# Requirement already satisfied: jinja2 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from scikit-learn->sentence_transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/luka/PycharmProjects/eeg-and-audio-analysis/.venv/lib/python3.11/site-packages (from scikit-learn->sentence_transformers) (3.6.0)

# %%
from sentence_transformers import SentenceTransformer, util

# %%
model = SentenceTransformer('all-mpnet-base-v2')

# %%
def cosine_distance(vec1, vec2):
    return 1 - util.cos_sim(vec1, vec2).item()

# %%
def word_distance(word1, word2):
    embeddings = model.encode([word1, word2], normalize_embeddings=True)
    return cosine_distance(embeddings[0], embeddings[1])

# %%
def batch_word_distance(word, word_list):
    embeddings = model.encode([word] + word_list, normalize_embeddings=True)
    word_vec = embeddings[0]
    word_list_vecs = embeddings[1:]
    distances = [cosine_distance(word_vec, w) for w in word_list_vecs]
    return distances

# %% [markdown]
# # Demo
# - SBERT converts any text (a word, phrase, slogan, brand name, etc.) into a high-dimensional vector (usually 768-D).
# - Two semantically similar phrases (e.g., “Apple” and “innovation”) will have vectors close together in that space; dissimilar ones (e.g., “Apple” and “diesel engine”) will be far apart.
# - We can quantify that closeness with cosine similarity or cosine distance.
#
# $$\text{Cosine distance} = 1 - \frac{v_1 \cdot v_2}{||v_1|| \, ||v_2||}$$

# %%
brand = "Apple"
targets = ["innovation", "creativity", "battery", "diesel engine"]

distances = batch_word_distance(brand, targets)
print(f"Distances from '{brand}':")
for target, dist in zip(targets, distances):
    print(f"  to '{target}': {dist:.4f}")
# Out:
# Distances from 'Apple':
#   to 'innovation': 0.6278
#   to 'creativity': 0.7024
#   to 'battery': 0.5826
#   to 'diesel engine': 0.8319

# %% [markdown]
# ## Create a lexicon of words

# %%
import pandas as pd
import csv

# %%
# Load candidate lexicon with metadata
# columns required: word, length, zipf, concreteness, valence, arousal, pos
# lex = pd.read_csv("lexicon_with_norms.csv")
# # Basic filters
# lex = lex.query("4 <= length <= 9 and 2.5 <= zipf <= 5").copy()
# lex = lex[~lex.word.str.contains(r"[^a-zA-Z-]")]

# %%
swow = pd.read_csv(
    "./lexicon/SWOW-EN18/strength.SWOW-EN.R123.20180827.csv",
    sep="\t",
    quoting=csv.QUOTE_NONE,
    escapechar=None,
    engine="python"
)

# %%
swow
# Out:
#               cue response  R123    N  R123.Strength
# 0               a      one    32  270       0.118519
# 1               a      the    27  270       0.100000
# 2               a       an    19  270       0.070370
# 3               a        b    14  270       0.051852
# 4               a   single     9  270       0.033333
# ...           ...      ...   ...  ...            ...
# 1389706  zucchini     thin     1  283       0.003534
# 1389707  zucchini   veggie     1  283       0.003534
# 1389708  zucchini  veggies     1  283       0.003534
# 1389709  zucchini   weapon     1  283       0.003534
# 1389710  zucchini     what     1  283       0.003534
#
# [1389711 rows x 5 columns]
